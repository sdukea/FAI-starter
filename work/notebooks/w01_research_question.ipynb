# %% [markdown]
# # ML-02 — Research Question and Provisional Lane
#
# [![Open In Colab](https://colab.research.google.com/assets/colab-badge.svg)](https://colab.research.google.com/github/sdukea/FAI-starter/blob/main/work/notebooks/w01_research_question.ipynb?flush_cache=true)
#
# This skeleton is yours to fill. Work the sections **in order** — each one has a one-line hint. Simple words, honest numbers.
#
# > Working with an AI assistant? Tell it to read `skills/README.md` first and load the one skill this assignment names on its card.

# %% [markdown]
# ## 1. My lane (or freestyle) and why
#
# *Name your lane — or say 'freestyle' and describe your own question. One short paragraph: why this one?*
#
# ---
#
# <br>
#
# Chosen lane: **Ranking Signal Analysis**
#
# <br>
#
# When I realized that my very own clothing brand - Getor - needed marketing, I came across this rather eccentric term; SEO. It stood for 'search engine optimization', and it felt very important at the time considering the dire need for distribution. Sadly, Getor never practiced having good search optimization (had to focus on school).
#
# Now, after examining all the lanes, ranking signal analysis, or search ranking, interplayed well with some of the experiences I've had around trying to appear first in search results. I knew I had to be at the forefront of this and go deeper.

# %%
# This cell is for CODE (numbers, a query, a check).
# Write your text answer in the cell ABOVE this one — typing sentences here breaks Run All.

# Took two paragraphs, though. (reckoned it was a good story to bring up)

# %% [markdown]
# ## 2. The question: decision, action, cost of a wrong call
#
# *What decision does your work improve? Who acts on it? What does a wrong recommendation cost?*
#
# ---
#
# <br>
#
# The decision is to help determine which webpages should be prioritized for investigation based on their ranking signals, so that editors and SEO teams focus on pages with the greatest opportunity for improvement.
#
# SEO analysts, content strategists, or editors who decide which pages to review, update, or optimize.
#
# If the recommendation is incorrect, valuable engineering and editorial time may be spent on low-impact pages while high-impact pages are overlooked. This can also delay improvements in search performance.

# %%
# This cell is for CODE (numbers, a query, a check).
# Write your text answer in the cell ABOVE this one — typing sentences here breaks Run All.

# %% [markdown]
# ## 3. Quick look at the data (2-3 real numbers)
#
# *Load the starter CSV below and show 2-3 real numbers that make your lane look worth the next 7 weeks.*

# %%
# This cell is for CODE (numbers, a query, a check).
# Write your text answer in the cell ABOVE this one — typing sentences here breaks Run All.

import pandas as pd

d = pd.read_csv('D:\\Syon\\Success\\Internships\\ML Intern - FlyRank AI\\FAI-starter\\data\\raw\\content_refresh_anonymized.csv')

# need to know: 
# what's the median CTR and position, size of data and missing positions

# understanding: 
# 'positions' is the most important feature and refers to where a webpage appeared in Google search results
# Google Search Console averages the different positions a webpage takes for many different searches that
# are contextually related, giving out something like 'avg_position = 5'
# 'CTR' or the click-through-rate is also important – if the median is low, it shows that most pages 
# recieve little engagement. This actually makes it worthwhile to understand why.

print(f"Rows: {len(d)}")
print(f"Median CTR: {d["ctr"].median()}")
print(f"Median average position: {d["avg_position"].replace(0, pd.NA).median()}")
print(f"Count of pages with no ranking data: {(d["avg_position"] == 0).sum()}")
# Out:
# Rows: 30000
# Median CTR: 0.07
# Median average position: 11.4
# Count of pages with no ranking data: 1205

# %% [markdown]
# ## 4. Careful words: what I can and can't claim
#
# *Write what your work will be able to say (observed, directional, decision-support) — and what it never will (causal proof, 'predicting Google').*
#
# ---
#
# <br>

# %%
# This cell is for CODE (numbers, a query, a check).
# Write your text answer in the cell ABOVE this one — typing sentences here breaks Run All.

# %% [markdown]
# ## Self-check
#
# Before you submit, confirm each line honestly:
#
# - [ ] Every section above is filled — markdown thinking AND the code that backs it
# - [ ] The notebook runs top to bottom with no errors (Runtime → Run all)
# - [ ] No client names, URLs, or private queries anywhere
# - [ ] My claims use careful words: observed, measured, directional, decision-support
# - [ ] Committed to my repo under `work/notebooks/` — then submit your repo URL on the card. Done.
