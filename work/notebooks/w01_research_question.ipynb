# %% [markdown]
# # ML-02 — Research Question and Provisional Lane
#
# [![Open In Colab](https://colab.research.google.com/assets/colab-badge.svg)](https://colab.research.google.com/github/sdukea/FAI-starter/blob/main/work/notebooks/w01_research_question.ipynb?flush_cache=true)
#
# This skeleton is yours to fill. Work the sections **in order** — each one has a one-line hint. Simple words, honest numbers.
#
# > Working with an AI assistant? Tell it to read `skills/README.md` first and load the one skill this assignment names on its card.

# %% [markdown]
# ## 1. My lane (or freestyle) and why
#
# *Name your lane — or say 'freestyle' and describe your own question. One short paragraph: why this one?*
#
# ---
#
# <br>
#
# Chosen lane: **Content opportunity scoring**
#
# Lane 2 lets me spend my limited time on genuinely rehearsing the hard skills - diagnosing leakage, choosing the metric that matches the decision, validating honestly, reading errors - rather than spending a large fraction of your time simply constructing a valid problem to study in the first place. The other lanes either don't have this comparative structure at all, or make you build it from zero under real leakage risk. This lane hands me a working, already-validated instance of the exact reasoning pattern Google (or any serious ML organization) will interview you on, and lets me go deep on critiquing and improving it rather than bootstrapping it.

# %%
# This cell is for CODE (numbers, a query, a check).
# Write your text answer in the cell ABOVE this one — typing sentences here breaks Run All.

# Took two paragraphs, though. (reckoned it was a good story to bring up)

# %% [markdown]
# ## 2. The question: decision, action, cost of a wrong call
#
# *What decision does your work improve? Who acts on it? What does a wrong recommendation cost?*
#
# ---
#
# <br>
#
# The decision is to determine which webpages should be prioritized for review based on observable search and content signals, enabling teams to focus on pages with the greatest opportunity for improvement.
#
# SEO analysts, content strategists, and editors who decide which pages to refresh, expand, optimize, monitor, or retire.
#
# If the recommendation is incorrect, valuable editorial and optimization effort may be spent on low-impact pages while high-impact opportunities are overlooked. This can delay improvements in search visibility, reduce the effectiveness of content operations, and lower confidence in the prioritization system.

# %%
# This cell is for CODE (numbers, a query, a check).
# Write your text answer in the cell ABOVE this one — typing sentences here breaks Run All.

# %% [markdown]
# ## 3. Quick look at the data (2-3 real numbers)
#
# *Load the starter CSV below and show 2-3 real numbers that make your lane look worth the next 7 weeks.*

# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

from pathlib import Path

base = Path('D:/Syon/Success/Internships/ML Intern - FlyRank AI/FAI-starter')
fp = base / 'data' / 'raw' / 'content_refresh_anonymized.csv'
df = pd.read_csv(fp)

# number of pages
# why: this answers why people can't reivew everything manually

print(f"Number of rows to review (too big): {len(df)}")

# pages that are already declining
# why: this helps with screening the required only
# Out:
# Number of rows to review (too big): 30000

# %% [markdown]
# ## 4. Careful words: what I can and can't claim
#
# *Write what your work will be able to say (observed, directional, decision-support) — and what it never will (causal proof, 'predicting Google').*
#
# ---
#
# <br>
#
#
# - It can identify pages that should be prioritized for review based on observable search and content signals.
# - It can provide evidence-based rankings that help identify pages with the greatest opportunity for refresh, optimization, or monitoring.
# - It can support SEO analysts, content strategists, and editors in deciding where to focus limited review effort.
# - It can improve content prioritization using patterns learned from historical search and engagement data.
#
# <br>
#
# - It cannot prove that refreshing a page will improve its search performance.
# - It cannot predict or reverse-engineer Google's ranking algorithm.
# - It cannot guarantee that a recommended action will lead to higher rankings, traffic, or engagement.
# - It cannot establish causal relationships without controlled experiments or A/B testing.

# %%
# This cell is for CODE (numbers, a query, a check).
# Write your text answer in the cell ABOVE this one — typing sentences here breaks Run All.

# %% [markdown]
# ## Self-check
#
# Before you submit, confirm each line honestly:
#
# - [x] Every section above is filled — markdown thinking AND the code that backs it
# - [x] The notebook runs top to bottom with no errors (Runtime → Run all)
# - [x] No client names, URLs, or private queries anywhere
# - [x] My claims use careful words: observed, measured, directional, decision-support
# - [x] Committed to my repo under `work/notebooks/` — then submit your repo URL on the card. Done.
